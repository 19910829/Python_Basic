# %% [markdown]
# # NUMPY

# %%
#Can you check if the given string is a palindrome or not?
def is_palindrome(s):
    return s == s[::-1]

# %%
#Given an array A and value K, print all the pairs a, b such that a+b=K.
def find_pairs(A, K):
    pairs = []
    for i in range(len(A)):
        for j in range(i+1, len(A)):
            if A[i] + A[j] == K:
                pairs.append((A[i], A[j]))
    return pairs

# %%
#How would you implement a stack using an array or a linked list?
class Stack:
    def __init__(self):
        self.items = []

    def push(self, item):
        self.items.append(item)

    def pop(self):
        return self.items.pop()

    def is_empty(self):
        return len(self.items) == 0

    def size(self):
        return len(self.items)

# %%
class Node:
    def __init__(self, data=None):
        self.data = data
        self.next = None

class Stack:
    def __init__(self):
        self.top = None

    def push(self, item):
        new_node = Node(item)
        new_node.next = self.top
        self.top = new_node

    def pop(self):
        if self.top is None:
            raise Exception('Stack is empty')
        item = self.top.data
        self.top = self.top.next
        return item

    def is_empty(self):
        return self.top is None

    def size(self):
        count = 0
        current = self.top
        while current is not None:
            count += 1
            current = current.next
        return count

# %%
#How would you find the kth largest element in an unsorted array?
def find_kth_largest(A, k):
    sorted_A = sorted(A)
    return sorted_A[-k]

# %%
#How would you implement a binary search algorithm?
def binary_search(A, x):
    left = 0
    right = len(A) - 1
    while left <= right:
        mid = (left + right) // 2
        if A[mid] == x:
            return mid
        elif A[mid] < x:
            left = mid + 1
        else:
            right = mid - 1
    return -1

# %%
#How would you implement a hash table?
class HashTable:
    def __init__(self, size=10):
        self.size = size
        self.table = [[] for _ in range(size)]

    def hash_function(self, key):
        return hash(key) % self.size

    def insert(self, key, value):
        index = self.hash_function(key)
        for item in self.table[index]:
            if item[0] == key:
                item[1] = value
                return
        self.table[index].append([key, value])

    def search(self, key):
        index = self.hash_function(key)
        for item in self.table[index]:
            if item[0] == key:
                return item[1]
        raise KeyError(key)

    def delete(self, key):
        index = self.hash_function(key)
        for i, item in enumerate(self.table[index]):
            if item[0] == key:
                del self.table[index][i]
                return
        raise KeyError(key)

# %%
#How would you find the shortest path between two nodes in a graph?
from collections import deque

def shortest_path(graph, start, end):
    queue = deque([(start, [start])])
    visited = set()
    while queue:
        node, path = queue.popleft()
        if node == end:
            return path
        if node not in visited:
            visited.add(node)
            for neighbor in graph[node]:
                queue.append((neighbor, path + [neighbor]))
    raise ValueError('No path found')

# %%
def collatz(n):
    inc = 1
    c = []
    c.append(n)
    
    while n > 1:
        if n % 2 == 0:
            n = n / 2
        else:
            n = (3 * n) + 1
        c.append(n)
    return c

j = int(input())
print(collatz(j))
# Out:
# 3
# [3, 10, 5.0, 16.0, 8.0, 4.0, 2.0, 1.0]

# %%
def Table(n):
    for i in range(1,11):
        for j in range(1, n+1):
            print(i * j,end='\t')
        print()
mul = int(input())
Table(mul)
# Out:
# 5
# 1	2	3	4	5
# 2	4	6	8	10
# 3	6	9	12	15
# 4	8	12	16	20
# 5	10	15	20	25
# 6	12	18	24	30
# 7	14	21	28	35
# 8	16	24	32	40
# 9	18	27	36	45
# 10	20	30	40	50

# %% [markdown]
# # PANDAS

# %%
import pandas as pd
import numpy as np

# %%
movies = pd.read_csv("top_movies_data.csv")

# %%
movies.head()
# Out:
#    production_year       id                                       title  \
# 0             2006  4103791  Pirates of the Caribbean: Dead Man's Chest
# 1             2006  4022547                         Night at the Museum
# 2             2006  3415583                                        Cars
# 3             2006  4587958                       X-Men: The Last Stand
# 4             2006  4351263                           The Da Vinci Code
#
#                    directors                                    genres  \
# 0            Verbinski, Gore                  Action|Adventure|Fantasy
# 1                Levy, Shawn           Adventure|Comedy|Family|Fantasy
# 2  Lasseter, John|Ranft, Joe             Animation|Comedy|Family|Sport
# 3              Ratner, Brett  Action|Adventure|Fantasy|Sci-Fi|Thriller
# 4                Howard, Ron                          Mystery|Thriller
#
#                                        camera_format negative_format  \
# ...

# %%
movies.shape
# Out:
# (1195, 10)

# %%
directors = pd.read_csv("top_directors_data.csv")

# %%
directors.head()
# Out:
#    production_year       id                     title      director  \
# 0             2009  4105528                 Planet 51  Abad, Javier
# 1             2006  3973646   Mission: Impossible III  Abrams, J.J.
# 2             2009  4272468                 Star Trek  Abrams, J.J.
# 3             2011  4291293                   Super 8  Abrams, J.J.
# 4             2013  4272595  Star Trek: Into Darkness  Abrams, J.J.
#
#    director_id                                 co_directors  \
# 0         1975  Abad, Javier|Blanco, Jorge|Martínez, Marcos
# 1         7718                                 Abrams, J.J.
# 2         7718                                 Abrams, J.J.
# 3         7718                                 Abrams, J.J.
# 4         7718                                 Abrams, J.J.
#
#        co_directors_id                                    genres  \
# 0  1516774|1975|233690  Adventure|Animation|Comedy|Family|Sci-Fi
# ...

# %%
directors.shape
# Out:
# (3635, 11)

# %%
 pd.DataFrame([
     ["A",30,"Mumbai"],
 ["B",20,"Pune"],
 ["C",40,"Nagpur"]
 ],
 columns = ["Name","Age","City"])
# Out:
#   Name  Age    City
# 0    A   30  Mumbai
# 1    B   20    Pune
# 2    C   40  Nagpur

# %%
pd.DataFrame({"Name":["A","B","C"],
             "Age":[30,20,40],
             "City":["Mumbai","Pune","Nagpur"]})
# Out:
#   Name  Age    City
# 0    A   30  Mumbai
# 1    B   20    Pune
# 2    C   40  Nagpur

# %%
dir_copy = pd.read_csv("top_directors_data.csv")
dir_copy.set_index('id',inplace=True)

# %%
dir_copy
# Out:
#          production_year                        title        director  \
# id
# 4105528             2009                    Planet 51    Abad, Javier
# 3973646             2006      Mission: Impossible III    Abrams, J.J.
# 4272468             2009                    Star Trek    Abrams, J.J.
# 4291293             2011                      Super 8    Abrams, J.J.
# 4272595             2013     Star Trek: Into Darkness    Abrams, J.J.
# ...                  ...                          ...             ...
# 3499419             2008                     Defiance   Zwick, Edward
# 3915042             2010           Love & Other Drugs   Zwick, Edward
# 4089040             2014               Pawn Sacrifice   Zwick, Edward
# 3778795             2016  Jack Reacher: Never Go Back   Zwick, Edward
# 3312301             2006      Art School Confidential  Zwigoff, Terry
#
#          director_id                                 co_directors  \
# id
# ...

# %%
dir_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3635 entries, 4105528 to 3312301
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   production_year  3635 non-null   int64
#  1   title            3635 non-null   object
#  2   director         3635 non-null   object
#  3   director_id      3635 non-null   int64
#  4   co_directors     3635 non-null   object
#  5   co_directors_id  3635 non-null   object
#  6   genres           3614 non-null   object
#  7   cameras          2071 non-null   object
#  8   negative_format  2213 non-null   object
#  9   film_type        3635 non-null   object
# dtypes: int64(2), object(8)
# memory usage: 312.4+ KB

# %%
dir_copy.iloc[1]
# Out:
# production_year                                                 2006
# title                                        Mission: Impossible III
# director                                                Abrams, J.J.
# director_id                                                     7718
# co_directors                                            Abrams, J.J.
# co_directors_id                                                 7718
# genres                                     Action|Adventure|Thriller
# cameras            Arriflex 235, Panavision C-Series Lenses|Arrif...
# negative_format                                          35 mm|Video
# film_type                                                        D|F
# Name: 3973646, dtype: object

# %%
dir_copy.loc[4272595]
# Out:
# production_year                                                 2013
# title                                       Star Trek: Into Darkness
# director                                                Abrams, J.J.
# director_id                                                     7718
# co_directors                                            Abrams, J.J.
# co_directors_id                                                 7718
# genres                                       Action|Adventure|Sci-Fi
# cameras            Arriflex 435 ES, Panavision Primo, C-, E-Serie...
# negative_format                              35 mm|65 mm|Redcode RAW
# film_type                                                        D|F
# Name: 4272595, dtype: object

# %%
 dir_copy.loc[3973646:4272595 ,'production_year':'director']
# Out:
#          production_year                     title      director
# id
# 3973646             2006   Mission: Impossible III  Abrams, J.J.
# 4272468             2009                 Star Trek  Abrams, J.J.
# 4291293             2011                   Super 8  Abrams, J.J.
# 4272595             2013  Star Trek: Into Darkness  Abrams, J.J.

# %%
dir_copy.iloc[1:3]
# Out:
#          production_year                    title      director  director_id  \
# id
# 3973646             2006  Mission: Impossible III  Abrams, J.J.         7718
# 4272468             2009                Star Trek  Abrams, J.J.         7718
#
#          co_directors co_directors_id                     genres  \
# id
# 3973646  Abrams, J.J.            7718  Action|Adventure|Thriller
# 4272468  Abrams, J.J.            7718    Action|Adventure|Sci-Fi
#
#                                                    cameras negative_format  \
# id
# 3973646  Arriflex 235, Panavision C-Series Lenses|Arrif...     35 mm|Video
# 4272468  Arriflex 435 ES, Panavision Primo Lenses|Panav...           35 mm
#
#         film_type
# id
# 3973646       D|F
# 4272468         F

# %%
dir_copy['director']
# Out:
# id
# 4105528      Abad, Javier
# 3973646      Abrams, J.J.
# 4272468      Abrams, J.J.
# 4291293      Abrams, J.J.
# 4272595      Abrams, J.J.
#                 ...
# 3499419     Zwick, Edward
# 3915042     Zwick, Edward
# 4089040     Zwick, Edward
# 3778795     Zwick, Edward
# 3312301    Zwigoff, Terry
# Name: director, Length: 3635, dtype: object

# %%
dir_copy.rename({"title":"Title"},axis=1)
# Out:
#          production_year                        Title        director  \
# id
# 4105528             2009                    Planet 51    Abad, Javier
# 3973646             2006      Mission: Impossible III    Abrams, J.J.
# 4272468             2009                    Star Trek    Abrams, J.J.
# 4291293             2011                      Super 8    Abrams, J.J.
# 4272595             2013     Star Trek: Into Darkness    Abrams, J.J.
# ...                  ...                          ...             ...
# 3499419             2008                     Defiance   Zwick, Edward
# 3915042             2010           Love & Other Drugs   Zwick, Edward
# 4089040             2014               Pawn Sacrifice   Zwick, Edward
# 3778795             2016  Jack Reacher: Never Go Back   Zwick, Edward
# 3312301             2006      Art School Confidential  Zwigoff, Terry
#
#          director_id                                 co_directors  \
# id
# ...

# %%
dir_copy.rename({"director":"directors"},axis=1,inplace=True)

# %%
dir_copy
# Out:
#          production_year                        Title       directors  \
# id
# 4105528             2009                    Planet 51    Abad, Javier
# 3973646             2006      Mission: Impossible III    Abrams, J.J.
# 4272468             2009                    Star Trek    Abrams, J.J.
# 4291293             2011                      Super 8    Abrams, J.J.
# 4272595             2013     Star Trek: Into Darkness    Abrams, J.J.
# ...                  ...                          ...             ...
# 3499419             2008                     Defiance   Zwick, Edward
# 3915042             2010           Love & Other Drugs   Zwick, Edward
# 4089040             2014               Pawn Sacrifice   Zwick, Edward
# 3778795             2016  Jack Reacher: Never Go Back   Zwick, Edward
# 3312301             2006      Art School Confidential  Zwigoff, Terry
#
#          director_id                                 co_directors  \
# id
# ...

# %%
movies.isnull()
# Out:
#       production_year     id  title  directors  genres  camera_format  \
# 0               False  False  False      False   False          False
# 1               False  False  False      False   False          False
# 2               False  False  False      False   False           True
# 3               False  False  False      False   False          False
# 4               False  False  False      False   False          False
# ...               ...    ...    ...        ...     ...            ...
# 1190            False  False  False      False   False          False
# 1191            False  False  False      False   False          False
# 1192            False  False  False      False   False          False
# 1193            False  False  False      False   False          False
# 1194            False  False  False      False   False          False
#
#       negative_format  budget  budget_source  film_type
# 0               False   False          False      False
# ...

# %%
movies.dropna()
# Out:
#       production_year       id                                       title  \
# 0                2006  4103791  Pirates of the Caribbean: Dead Man's Chest
# 1                2006  4022547                         Night at the Museum
# 3                2006  4587958                       X-Men: The Last Stand
# 4                2006  4351263                           The Da Vinci Code
# 5                2006  4292783                            Superman Returns
# ...               ...      ...                                         ...
# 1188             2017  3773879                           It Comes at Night
# 1191             2017  4375083                        The Greatest Showman
# 1192             2016  4367698                                 The Founder
# 1193             2017  3342703                         Battle of the Sexes
# 1194             2017  4332562                                The Beguiled
#
#                             directors  \
# ...

# %%
movies.shape
# Out:
# (1195, 10)

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1195 entries, 0 to 1194
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   production_year  1195 non-null   int64
#  1   id               1195 non-null   int64
#  2   title            1195 non-null   object
#  3   directors        1195 non-null   object
#  4   genres           1195 non-null   object
#  5   camera_format    1025 non-null   object
#  6   negative_format  1104 non-null   object
#  7   budget           1195 non-null   int64
#  8   budget_source    1195 non-null   object
#  9   film_type        1195 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 93.5+ KB

# %%
dir_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3635 entries, 4105528 to 3312301
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   production_year  3635 non-null   int64
#  1   Title            3635 non-null   object
#  2   directors        3635 non-null   object
#  3   director_id      3635 non-null   int64
#  4   co_directors     3635 non-null   object
#  5   co_directors_id  3635 non-null   object
#  6   genres           3614 non-null   object
#  7   cameras          2071 non-null   object
#  8   negative_format  2213 non-null   object
#  9   film_type        3635 non-null   object
# dtypes: int64(2), object(8)
# memory usage: 441.4+ KB

# %%
mov_copy = pd.read_csv("top_movies_data.csv")
mov_copy.set_index('id',inplace=True)

# %%
df = mov_copy.merge(dir_copy, how='left',left_on="directors",right_on="directors")

# %%
df.head()
# Out:
#    production_year_x                                       title  \
# 0               2006  Pirates of the Caribbean: Dead Man's Chest
# 1               2006  Pirates of the Caribbean: Dead Man's Chest
# 2               2006  Pirates of the Caribbean: Dead Man's Chest
# 3               2006  Pirates of the Caribbean: Dead Man's Chest
# 4               2006  Pirates of the Caribbean: Dead Man's Chest
#
#          directors                  genres_x  \
# 0  Verbinski, Gore  Action|Adventure|Fantasy
# 1  Verbinski, Gore  Action|Adventure|Fantasy
# 2  Verbinski, Gore  Action|Adventure|Fantasy
# 3  Verbinski, Gore  Action|Adventure|Fantasy
# 4  Verbinski, Gore  Action|Adventure|Fantasy
#
#                                        camera_format negative_format_x  \
# 0  Arriflex 235, Panavision Primo Lenses|Panavisi...             35 mm
# 1  Arriflex 235, Panavision Primo Lenses|Panavisi...             35 mm
# 2  Arriflex 235, Panavision Primo Lenses|Panavisi...             35 mm
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5608 entries, 0 to 5607
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   production_year_x  5608 non-null   int64
#  1   title              5608 non-null   object
#  2   directors          5608 non-null   object
#  3   genres_x           5608 non-null   object
#  4   camera_format      5056 non-null   object
#  5   negative_format_x  5200 non-null   object
#  6   budget             5608 non-null   int64
#  7   budget_source      5608 non-null   object
#  8   film_type_x        5608 non-null   object
#  9   production_year_y  5487 non-null   float64
#  10  Title              5487 non-null   object
#  11  director_id        5487 non-null   float64
#  12  co_directors       5487 non-null   object
#  13  co_directors_id    5487 non-null   object
#  14  genres_y           5462 non-null   object
#  15  cameras            4017 non-null   object
# ...

# %%
df.drop(['budget_source'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    production_year_x                                       title  \
# 0               2006  Pirates of the Caribbean: Dead Man's Chest
# 1               2006  Pirates of the Caribbean: Dead Man's Chest
# 2               2006  Pirates of the Caribbean: Dead Man's Chest
# 3               2006  Pirates of the Caribbean: Dead Man's Chest
# 4               2006  Pirates of the Caribbean: Dead Man's Chest
#
#          directors                  genres_x  \
# 0  Verbinski, Gore  Action|Adventure|Fantasy
# 1  Verbinski, Gore  Action|Adventure|Fantasy
# 2  Verbinski, Gore  Action|Adventure|Fantasy
# 3  Verbinski, Gore  Action|Adventure|Fantasy
# 4  Verbinski, Gore  Action|Adventure|Fantasy
#
#                                        camera_format negative_format_x  \
# 0  Arriflex 235, Panavision Primo Lenses|Panavisi...             35 mm
# 1  Arriflex 235, Panavision Primo Lenses|Panavisi...             35 mm
# 2  Arriflex 235, Panavision Primo Lenses|Panavisi...             35 mm
# ...

# %%
df.loc[df["directors"]=="Fleischer, Ruben",["Title"]].count()
# Out:
# Title    21
# dtype: int64

# %%
df["directors"].value_counts()
# Out:
# Perry, Tyler                   336
# Eastwood, Clint                 90
# Scott, Ridley                   84
# Soderbergh, Steven              78
# Levy, Shawn                     64
#                               ...
# Mårlind, Måns|Stein, Björn       1
# Williams, Steve 'Spaz'           1
# Ellin, Doug                      1
# Moreau, David|Palud, Xavier      1
# Garland, Alex                    1
# Name: directors, Length: 660, dtype: int64

# %%
df.groupby("directors")["Title"].count()
# Out:
# directors
# Abad, Javier|Blanco, Jorge|Martínez, Marcos     0
# Abrams, J.J.                                   25
# Abu-Assad, Hany                                 6
# Acker, Shane                                    2
# Adamson, Andrew                                 3
#                                                ..
# Zucker, David                                   3
# Zwart, Harald                                  18
# Zwick, Edward                                  15
# bo Odar, Baran                                  4
# del Toro, Guillermo                            20
# Name: Title, Length: 660, dtype: int64

# %%
"""NumPy is a library for numerical computing in Python,providing support for large, 
multi-dimensional arrays and matrices, along with a collection of mathematical functions."""
import numpy as np

# Creating a 1D array
arr = np.array([1, 2, 3, 4, 5])

# Creating a 2D array
matrix = np.array([[1, 2, 3], [4, 5, 6]])

# Performing operations on arrays
result = arr + 10
print(result)

# Computing matrix multiplication
product = np.dot(matrix, arr)
print(product)
# Out:
# [11 12 13 14 15]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 16
#      13 print(result)
#      15 # Computing matrix multiplication
# ---> 16 product = np.dot(matrix, arr)
#      17 print(product)
#
# File <__array_function__ internals>:180, in dot(*args, **kwargs)
#
# ValueError: shapes (2,3) and (5,) not aligned: 3 (dim 1) != 5 (dim 0)

# %%
"""Pandas is a library for data manipulation and analysis. It provides data structures such as DataFrames for 
efficient handling of structured data."""
import pandas as pd

# Creating a DataFrame from a dictionary
data = {'Name': ['Alice', 'Bob', 'Charlie'],
        'Age': [25, 30, 35]}
df = pd.DataFrame(data)

# Accessing columns and rows
print(df['Name'])
print(df.iloc[0])

# Applying operations on columns
df['Age'] = df['Age'] + 1

# Filtering rows based on a condition
filtered_df = df[df['Age'] > 30]
print(filtered_df)
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# Name: Name, dtype: object
# Name    Alice
# Age        25
# Name: 0, dtype: object
#       Name  Age
# 1      Bob   31
# 2  Charlie   36

# %%
"""Matplotlib is a plotting library that provides a MATLAB-like interface for creating static, animated, and interactive visualizations in Python."""
import matplotlib.pyplot as plt

# Line plot
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]
plt.plot(x, y)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Line Plot')
plt.show()

# Scatter plot
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]
plt.scatter(x, y)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Scatter Plot')
plt.show()

# %%
"""TensorFlow is an open-source machine learning framework that allows you to build and train various types of machine learning models, including neural networks."""

import tensorflow as tf

# Creating a simple neural network model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(64, activation='relu', input_shape=(784,)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])

# Compiling the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Training the model
model.fit(x_train, y_train, epochs=10, batch_size=32)

# Making predictions
predictions = model.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[14], line 3
#       1 """TensorFlow is an open-source machine learning framework that allows you to build and train various types of machine learning models, including neural networks."""
# ----> 3 import tensorflow as tf
#       5 # Creating a simple neural network model
#       6 model = tf.keras.Sequential([
#       7     tf.keras.layers.Dense(64, activation='relu', input_shape=(784,)),
#       8     tf.keras.layers.Dense(64, activation='relu'),
#       9     tf.keras.layers.Dense(10, activation='softmax')
#      10 ])
#
# ModuleNotFoundError: No module named 'tensorflow'
